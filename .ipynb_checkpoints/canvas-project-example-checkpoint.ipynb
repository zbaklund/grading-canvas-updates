# %%
import pandas as pd
import numpy as np
import json, os, math
from collections import defaultdict as ddict

# %%
# adding grades for another project just involves changing these and re-running

# file exported from Canvas
file_a = "2021-11-09T2255_Grades-FA21_COMPSCI_220_001.csv"
# new file we'll create to be imported to Canvas
file_b = "canvas-new.csv"

# will update this project and all before it
last_proj = 8

# this directory contains p1.json, p2.json, etc
# grades_dir = ("/Users", "trh", "g", "caraza-harter-com", "tools", "grades")
#grades_dir = ("/Users", "souravp", "Documents", "TA", "Fall20", "caraza-harter-com", "tools", "grades")
grades_dir = ("/home", "caday", "Documents", "caraza-harter-com", "cs220_tools", "grades")

# how many late days can they use before they get ZERO?
late_allowed = 12 # Should be 12, I changed it since we allowed late resubmission

# %%
# c is the canvas DataFrame
c = pd.read_csv(file_a)
c.head()
# Out:
#                 Student        ID SIS User ID           SIS Login ID  \
# 0       Points Possible       NaN         NaN                    NaN
# 1     ABBASZADEH, ARIAN  384159.0   UW904W244    ABBASZADEH@WISC.EDU
# 2        ABBOTT, GEORGE  309977.0   UW862D899      GHABBOTT@WISC.EDU
# 3    ABPLANALP, CAMERON  320483.0   UW861X664    CABPLANALP@WISC.EDU
# 4  Abrajan Rojas, Manny  327727.0   UW898X347  ABRAJANROJAS@WISC.EDU
#
#                                        Section  \
# 0                                          NaN
# 1  COMP SCI 220:LAB313 and COMP SCI 220:LEC001
# 2  COMP SCI 220:LAB315 and COMP SCI 220:LEC001
# 3  COMP SCI 220:LAB331 and COMP SCI 220:LEC003
# 4  COMP SCI 220:LAB342 and COMP SCI 220:LEC004
#
#    CS220 Student Information Survey (1350484)  Piazza sign-up (1351636)  \
# 0                                         1.0                       1.0
# 1                                         NaN                       NaN
# 2                                         NaN                       NaN
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
#
#    Project 1 (1364295)  Project 2 (1364297)  Project 3 (1364301)  ...  \
# 0                  1.0                  4.0                 4.00  ...
# 1                  1.0                  4.0                 0.00  ...
# 2                  1.0                  4.0                 4.00  ...
# 3                  1.0                  4.0                 3.76  ...
# 4                  1.0                  4.0                 0.00  ...
#
#    For Grad Students in 319 Final Score  \
# 0                           (read only)
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    For Grad Students in 319 Unposted Final Score  \
# 0                                    (read only)
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Honorlock exams Current Score  Honorlock exams Unposted Current Score  \
# 0                    (read only)                             (read only)
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            NaN                                     NaN
#
#    Honorlock exams Final Score  Honorlock exams Unposted Final Score  \
# 0                  (read only)                           (read only)
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                                   NaN
#
#    Current Score  Unposted Current Score  Final Score  Unposted Final Score
# 0    (read only)             (read only)  (read only)           (read only)
# 1          87.79                   87.79        43.19                 43.19
# 2          92.88                   92.88        51.46                 51.46
# 3          84.52                   84.52        48.37                 48.37
# 4          37.38                   37.38        23.31                 23.31
#
# [5 rows x 68 columns]

# %%
# c = c.iloc[1:, :].set_index("SIS Login ID")
# c.head()

# %%
# c.loc["ABBASBAYLI@WISC.EDU", "Project 1"] = 1
# c.head()
list(c)
# Out:
# ['Student',
#  'ID',
#  'SIS User ID',
#  'SIS Login ID',
#  'Section',
#  'CS220 Student Information Survey (1350484)',
#  'Piazza sign-up (1351636)',
#  'Project 1 (1364295)',
#  'Project 2 (1364297)',
#  'Project 3 (1364301)',
#  'Project 4 (1364303)',
#  'Project 5 (1364306)',
#  'Project 6 (1364308)',
#  'Project 7 (1364311)',
#  'Project 8 (1364313)',
#  'Project 9 (1364314)',
#  'Project 10 (1364316)',
#  'Project 11 (1364317)',
#  'Project 12 (1364318)',
#  'Project 13 (1364320)',
#  'Quiz1 (1354083)',
#  'Quiz2 (1362733)',
#  'Quiz 3 (1367092)',
#  'Quiz 4 (1370403)',
#  'Quiz 5 (1374568)',
#  'Quiz 8 (1384848)',
#  'Quiz 7 (1381618)',
#  'Quiz 6 (1378150)',
#  'Exam1 (1379056)',
#  'Exam2 (1379064)',
#  'Final (1379065)',
#  'Project part 1: proposal (1375438)',
#  'Project part 2: data set (1375440)',
#  'Project part 3: initial code (1375465)',
#  'Project part 4: final code (1375466)',
#  'Exam 1: HonorLock (1374208)',
#  'Communication Current Score',
#  'Communication Unposted Current Score',
#  'Communication Final Score',
#  'Communication Unposted Final Score',
#  'Projects Current Score',
#  'Projects Unposted Current Score',
#  'Projects Final Score',
#  'Projects Unposted Final Score',
#  'Quizzes Current Score',
#  'Quizzes Unposted Current Score',
#  'Quizzes Final Score',
#  'Quizzes Unposted Final Score',
#  'Exams Current Score',
#  'Exams Unposted Current Score',
#  'Exams Final Score',
#  'Exams Unposted Final Score',
#  'Imported Assignments Current Score',
#  'Imported Assignments Unposted Current Score',
#  'Imported Assignments Final Score',
#  'Imported Assignments Unposted Final Score',
#  'For Grad Students in 319 Current Score',
#  'For Grad Students in 319 Unposted Current Score',
#  'For Grad Students in 319 Final Score',
#  'For Grad Students in 319 Unposted Final Score',
#  'Honorlock exams Current Score',
#  'Honorlock exams Unposted Current Score',
#  'Honorlock exams Final Score',
#  'Honorlock exams Unposted Final Score',
#  'Current Score',
#  'Unposted Current Score',
#  'Final Score',
#  'Unposted Final Score']

# %%
def proj_col(p):
    pcol = None
    if(p=='final'):
        return 'Final project (833645)'
    for col in list(c):
        if col.startswith("Project "+str(p[1:])+" "):
            pcol = col
    assert(pcol != None)
    return pcol
# proj_col('final')
pcol = proj_col('p8')

# Final column name: Final project (833645)

# %%
idx = c["SIS Login ID"].str.split("@", expand=True)[0].str.lower()
idx = idx.rename("")
idx[0] = "points" # FIX this after tweaks
# idx[1] = "canvas_points"
c.set_index(idx, inplace=True)
c.head()
# Out:
#                            Student        ID SIS User ID  \
#
# points             Points Possible       NaN         NaN
# abbaszadeh       ABBASZADEH, ARIAN  384159.0   UW904W244
# ghabbott            ABBOTT, GEORGE  309977.0   UW862D899
# cabplanalp      ABPLANALP, CAMERON  320483.0   UW861X664
# abrajanrojas  Abrajan Rojas, Manny  327727.0   UW898X347
#
#                        SIS Login ID  \
#
# points                          NaN
# abbaszadeh      ABBASZADEH@WISC.EDU
# ghabbott          GHABBOTT@WISC.EDU
# cabplanalp      CABPLANALP@WISC.EDU
# abrajanrojas  ABRAJANROJAS@WISC.EDU
#
#                                                   Section  \
#
# points                                                NaN
# abbaszadeh    COMP SCI 220:LAB313 and COMP SCI 220:LEC001
# ghabbott      COMP SCI 220:LAB315 and COMP SCI 220:LEC001
# cabplanalp    COMP SCI 220:LAB331 and COMP SCI 220:LEC003
# abrajanrojas  COMP SCI 220:LAB342 and COMP SCI 220:LEC004
#
#               CS220 Student Information Survey (1350484)  \
#
# points                                               1.0
# abbaszadeh                                           NaN
# ghabbott                                             NaN
# cabplanalp                                           NaN
# abrajanrojas                                         NaN
#
#               Piazza sign-up (1351636)  Project 1 (1364295)  \
#
# points                             1.0                  1.0
# abbaszadeh                         NaN                  1.0
# ghabbott                           NaN                  1.0
# cabplanalp                         NaN                  1.0
# abrajanrojas                       NaN                  1.0
#
#               Project 2 (1364297)  Project 3 (1364301)  ...  \
#                                                         ...
# points                        4.0                 4.00  ...
# abbaszadeh                    4.0                 0.00  ...
# ghabbott                      4.0                 4.00  ...
# cabplanalp                    4.0                 3.76  ...
# abrajanrojas                  4.0                 0.00  ...
#
#               For Grad Students in 319 Final Score  \
#
# points                                 (read only)
# abbaszadeh                                     NaN
# ghabbott                                       NaN
# cabplanalp                                     NaN
# abrajanrojas                                   NaN
#
#               For Grad Students in 319 Unposted Final Score  \
#
# points                                          (read only)
# abbaszadeh                                              NaN
# ghabbott                                                NaN
# cabplanalp                                              NaN
# abrajanrojas                                            NaN
#
#               Honorlock exams Current Score  \
#
# points                          (read only)
# abbaszadeh                              NaN
# ghabbott                                NaN
# cabplanalp                              NaN
# abrajanrojas                            NaN
#
#               Honorlock exams Unposted Current Score  \
#
# points                                   (read only)
# abbaszadeh                                       NaN
# ghabbott                                         NaN
# cabplanalp                                       NaN
# abrajanrojas                                     NaN
#
#               Honorlock exams Final Score  \
#
# points                        (read only)
# abbaszadeh                            NaN
# ghabbott                              NaN
# cabplanalp                            NaN
# abrajanrojas                          NaN
#
#               Honorlock exams Unposted Final Score  Current Score  \
#
# points                                 (read only)    (read only)
# abbaszadeh                                     NaN          87.79
# ghabbott                                       NaN          92.88
# cabplanalp                                     NaN          84.52
# abrajanrojas                                   NaN          37.38
#
#               Unposted Current Score  Final Score  Unposted Final Score
#
# points                   (read only)  (read only)           (read only)
# abbaszadeh                     87.79        43.19                 43.19
# ghabbott                       92.88        51.46                 51.46
# cabplanalp                     84.52        48.37                 48.37
# abrajanrojas                   37.38        23.31                 23.31
#
# [5 rows x 68 columns]

# %%
# we'll merge all project grades here, ordered by project number
rows = []

# loop over project JSON files, updating Canvas
for i in range(1, last_proj+1):
    path = grades_dir + ("p%d.json"%i,)
    path = os.path.join(*path)
    with open(path) as f:
        rows += json.load(f)

# path = grades_dir + ("final.json",)
# path = os.path.join(*path)
# with open(path) as f:
#     rows += json.load(f)

# %%
c.loc["points"]
# Out:
# Student                                     Points Possible
# ID                                                      NaN
# SIS User ID                                             NaN
# SIS Login ID                                            NaN
# Section                                                 NaN
#                                                ...
# Honorlock exams Unposted Final Score            (read only)
# Current Score                                   (read only)
# Unposted Current Score                          (read only)
# Final Score                                     (read only)
# Unposted Final Score                            (read only)
# Name: points, Length: 68, dtype: object

# %%
total_late = ddict(int)

# update Canvas grades, cell-by-cell
for row in rows:
    net_id = row["net_id"]
    if not net_id in c.index:
        continue # they dropped?f
    
    pcol = proj_col(row["project"])
#     print(pcol)
    max_points = 100.
#     if(row["project"]=='p9' or row["project"]=='p10'):
#         max_points = 150.
#     if(row["project"]=='final'):
#         max_points = 27.
    possible = float(c.loc["points", pcol])
#     print(possible)
    score = round((row["score"] / max_points) * possible, 2)
    late = row["late_days"]
#     print(row['score'], score)
    
    if late > 0:
        total_late[net_id] += late
        if total_late[net_id] > late_allowed:
            warn = "WARNING: not counting '%s' grade of %d for '%s' due to lateness"
            print(warn % (pcol, score, net_id))
            score = 0

    # update Canvas if new grade is better
    try:
        prev = float(c.loc[net_id, pcol])
    except:
        prev = 0
#     if math.isnan(prev) or score >= prev or score <prev:
#         # update their canvas score
#         c.loc[net_id, pcol] = score
#     if prev == 0:
#         c.loc[net_id, pcol] = c.loc[net_id, pcol]
#         print("Keeping N/a", net_id, prev, score, pcol)
    if math.isnan(prev) or score >= (prev+0.01):
        # increase their canvas score
        c.loc[net_id, pcol] = score
        print("Updated for ", net_id, prev, score, pcol)
    if math.isnan(prev) or score <= (prev-0.01):
        warn = "WARNING: not reducing '%s' grade for '%s' from %f to %f"
        print(warn % (pcol, net_id, prev, score))
    if prev>4.0:
        c.loc[net_id, pcol] = score
        print("Clipped for ", net_id, prev, score, pcol)
# Out:
# Keeping N/a estai2 0.0 0.0 Project 1 (1364295)
# Keeping N/a knxiong2 0.0 0.0 Project 1 (1364295)
# Keeping N/a ddhanson3 0.0 0.0 Project 1 (1364295)
# Keeping N/a gtellezgiron 0.0 0.0 Project 1 (1364295)
# Keeping N/a gandjui 0.0 0.0 Project 1 (1364295)
# WARNING: not counting 'Project 2 (1364297)' grade of 4 for 'emkang2' due to lateness
# Keeping N/a emkang2 0.0 0 Project 2 (1364297)
# Keeping N/a estai2 0.0 0.0 Project 2 (1364297)
# Keeping N/a kmdavis22 0.0 0.0 Project 2 (1364297)
# Keeping N/a nefowler 0.0 0.0 Project 2 (1364297)
# Keeping N/a gandjui 0.0 0.0 Project 2 (1364297)
# Keeping N/a klichtman 0.0 0.0 Project 2 (1364297)
# Keeping N/a arpetersen2 0.0 0.0 Project 3 (1364301)
# Keeping N/a abrajanrojas 0.0 0.0 Project 3 (1364301)
# Keeping N/a mmotsinger 0.0 0.0 Project 3 (1364301)
# WARNING: not reducing 'Project 3 (1364301)' grade for 'cjowens2' from 4.000000 to 3.920000
# Keeping N/a shatsky 0.0 0.0 Project 3 (1364301)
# Keeping N/a emkang2 0.0 0.0 Project 3 (1364301)
# Keeping N/a mnliu 0.0 0.0 Project 3 (1364301)
# Keeping N/a estai2 0.0 0.0 Project 3 (1364301)
# Keeping N/a ramspott 0.0 0.0 Project 3 (1364301)
# Keeping N/a yvrao 0.0 0.0 Project 8 (1364313)
# Keeping N/a arhomberg 0.0 0.0 Project 8 (1364313)
# Keeping N/a atschmitt2 0.0 0.0 Project 8 (1364313)
# Keeping N/a gandjui 0.0 0.0 Project 8 (1364313)
# Keeping N/a seevenson 0.0 0.0 Project 8 (1364313)
# Keeping N/a ozaidan 0.0 0.0 Project 8 (1364313)
# Keeping N/a wwbeck2 0.0 0.0 Project 8 (1364313)
# Keeping N/a mddoran2 0.0 0.0 Project 8 (1364313)
# Keeping N/a hmjohnson24 0.0 0.0 Project 8 (1364313)
# Keeping N/a etferguson2 0.0 0.0 Project 8 (1364313)
# Keeping N/a gtradtke 0.0 0.0 Project 8 (1364313)
# Keeping N/a jma245 0.0 0.0 Project 8 (1364313)
# Keeping N/a bhamani 0.0 0.0 Project 8 (1364313)

# %%
total_late
# Out:
# defaultdict(int,
#             {'qbi5': 7,
#              'goleb': 7,
#              'pzhao57': 17,
#              'aatran2': 5,
#              'xshen99': 6,
#              'sanev': 31,
#              'jschweda': 8,
#              'dim4': 10,
#              'bzhang378': 1,
#              'jbyun6': 10,
#              'snkennedy2': 1,
#              'hfeng43': 4,
#              'emgore': 2,
#              'avena': 4,
#              'hliu649': 3,
#              'jlee888': 1,
#              'sheo9': 3,
#              'lee872': 1,
#              'saheyer': 2,
#              'dskwon2': 1,
#              'chen2235': 1,
#              'qjin42': 3,
#              'mrgackstette': 3,
#              'fwang264': 1,
#              'barredo': 3,
#              'xlu323': 3,
#              'zmayhew': 1,
#              'liu2263': 2,
#              'jsim24': 2,
#              'kins': 3,
#              'hli735': 1,
#              'stewari': 1,
#              'jchen837': 1,
#              'wxie48': 1,
#              'sgomez6': 1,
#              'zjia34': 1,
#              'hhan76': 1})

# %% [markdown]
# # apply zeros for cheating

# %%
for k in total_late:
    if total_late[k] > 10:
        print(k)
# Out:
# pzhao57
# sanev

# %%
def set_proj(df, net_id, proj, score):
    pcol = proj_col(proj)
#     for col in df.columns:
#         if col.split(" ")[0].lower() == proj.lower():
#             break
#     else:
#         raise Exception("could not find {} {}".format(net_id, proj))
    assert net_id in df.index
    df.loc[net_id, pcol] = score
        
with open("cheating.json") as f:
    cheating = json.load(f)
print(cheating)
for proj, students in cheating.items():
    for net_id, score in students.items():
        print("Set score to {} on {} for {}".format(score, proj, net_id))
        set_proj(c, net_id, proj, score)
# Out:
# {'p6': {'asingh232': 0, 'hkapur2': 0, 'bhasija': 0, 'vsagar': 0, 'sujadhav': 0, 'dlaufer': 0, 'bdwilson4': 0}, 'p7': {'sujadhav': 0, 'liao49': 0, 'yao95': 0}, 'p8': {'sujadhav': 0, 'eelgaard': 0, 'jmyles': 0, 'whbigelow': 0}, 'p9': {'hkapur2': 0, 'asingh232': 0}}
# Set score to 0 on p6 for asingh232
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_9711/2203460037.py in <module>
#      15     for net_id, score in students.items():
#      16         print("Set score to {} on {} for {}".format(score, proj, net_id))
# ---> 17         set_proj(c, net_id, proj, score)
#
# /tmp/ipykernel_9711/2203460037.py in set_proj(df, net_id, proj, score)
#       6 #     else:
#       7 #         raise Exception("could not find {} {}".format(net_id, proj))
# ----> 8     assert net_id in df.index
#       9     df.loc[net_id, pcol] = score
#      10
#
# AssertionError:

# %%
# create new Canvas CSV that we can import back in
c.to_csv(file_b, index=False)

# %%
c.describe()
# Out:
#                   ID  CS220 Student Information Survey (1350587)  \
# count      94.000000                                         1.0
# mean   303400.478723                                         1.0
# std     64384.350856                                         NaN
# min    161535.000000                                         1.0
# 25%    245248.750000                                         1.0
# 50%    305100.500000                                         1.0
# 75%    368406.250000                                         1.0
# max    406349.000000                                         1.0
#
#        Piazza sign-up (1353972)  Quiz 5 (1376711)  Quiz 6 (1379791)  \
# count                       1.0          87.00000         91.000000
# mean                        1.0          18.04023         19.299451
# std                         NaN           3.48520          1.231076
# min                         1.0           1.00000         13.670000
# 25%                         1.0          17.50000         19.000000
# 50%                         1.0          19.50000         20.000000
# 75%                         1.0          20.00000         20.000000
# max                         1.0          20.00000         20.000000
#
#        Project 1 (1364427)  Project 2 (1364405)  Project 3 (1364406)  \
# count            94.000000            94.000000            94.000000
# mean              0.952128             3.845957             3.728936
# std               0.208285             0.714675             0.820494
# min               0.000000             0.000000             0.000000
# 25%               1.000000             4.000000             3.840000
# 50%               1.000000             4.000000             4.000000
# 75%               1.000000             4.000000             4.000000
# max               1.000000             4.000000             4.000000
#
#        Project 4 (1364407)  Project 5 (1364408)  ...  Project 7 (1364411)  \
# count            94.000000            94.000000  ...            94.000000
# mean              3.777872             3.711915  ...             3.122128
# std               0.810949             0.823976  ...             1.626018
# min               0.000000             0.000000  ...             0.000000
# 25%               3.920000             3.840000  ...             3.970000
# 50%               4.000000             4.000000  ...             4.000000
# 75%               4.000000             4.000000  ...             4.000000
# max               4.000000             4.000000  ...             4.000000
#
#        Project 8 (1364413)  Project 9 (1364414)  Project 10 (1364415)  \
# count                  1.0                  1.0                   1.0
# mean                   4.0                  4.0                   4.0
# std                    NaN                  NaN                   NaN
# min                    4.0                  4.0                   4.0
# 25%                    4.0                  4.0                   4.0
# 50%                    4.0                  4.0                   4.0
# 75%                    4.0                  4.0                   4.0
# max                    4.0                  4.0                   4.0
#
#        Project 11 (1364417)  Project 12 (1364421)  Project 13 (1364422)  \
# count                   1.0                   1.0                   1.0
# mean                    4.0                   4.0                   4.0
# std                     NaN                   NaN                   NaN
# min                     4.0                   4.0                   4.0
# 25%                     4.0                   4.0                   4.0
# 50%                     4.0                   4.0                   4.0
# 75%                     4.0                   4.0                   4.0
# max                     4.0                   4.0                   4.0
#
#        Exam 1 (1373860)  Quiz 8 (1386220)  Quiz 7 (1383010)
# count          93.00000         10.000000         87.000000
# mean           28.11828         19.300000         18.172184
# std             5.11360          1.378405          2.448276
# min            11.00000         15.500000          9.330000
# 25%            25.00000         19.500000         17.000000
# 50%            30.00000         19.750000         19.000000
# 75%            32.00000         20.000000         20.000000
# max            35.00000         20.000000         20.000000
#
# [8 rows x 21 columns]

# %%
print("done!")
# Out:
# done!
